# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

traffic = pd.read_csv('../input/traffic-violations-in-maryland-county/Traffic_Violations.csv', dtype={'Charge' : 'str', 'Article' : 'str'})
traffic.shape
#traffic.head()
# I would try to remove invalid data values, but that information can't be reconstructed
# I only care about 'the most', so if some invalid data is the most, I can discard it then
# value_counts() can create bins, but only for numeric, so I'd have to use a converter on something like Time of Stop
colValCnts = traffic.Color.value_counts()
modelValCnts = traffic.Model.value_counts()
chargeValCnts = traffic.Charge.value_counts()
descValCnts = traffic.Description.value_counts()
subValCnts = traffic.SubAgency.value_counts()
makeValCnts = traffic.Make.value_counts()
yrValCnts = traffic.Year.value_counts()
print("The colors of vehicle most likely involved is ", colValCnts.index[0], colValCnts.index[1], colValCnts.index[2])
print("The models of vehicle most likely involved is ", modelValCnts.index[2], modelValCnts.index[3], modelValCnts.index[4])  # I have no idea what a 4S is, so we'll skip that. Alright, we'll skip TK too.
print("The most likely event according to the A Frequency, which is a term I made up just now is")
print(makeValCnts.index[0],colValCnts.index[0],modelValCnts.index[2],chargeValCnts.index[0],descValCnts.index[0],subValCnts.index[0],yrValCnts.index[0])
# There is no 2006.0 anywhere in the file, so I assume this is due to the year 2006 being printed as a decimal number
# Out:
# /kaggle/input/traffic-violations-in-maryland-county/Traffic_Violations.csv
# The colors of vehicle most likely involved is  BLACK SILVER WHITE
# The models of vehicle most likely involved is  ACCORD CIVIC CAMRY
# The most likely event according to the A Frequency, which is a term I made up just now is
# TOYOTA BLACK ACCORD 21-801.1 DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC CONTROL DEVICE INSTRUCTIONS 4th district, Wheaton 2006.0

# %%
# So I guess this is a cell.
